# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
ra = requests.get("https://google.co.in")

# %%
ra
# Out:
# <Response [200]>

# %%
ra.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-law.gif" itemprop="image"><meta content="Celebrating Dr. James Naismith" property="twitter:title"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="twitter:description"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="og:image"><meta content="784" property="og:image:width"><meta content="400" property="og:image:height">
# ...

# %%
ra.encoding
# Out:
# 'ISO-8859-1'

# %%
ra.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
rb = requests.get("https://api.github.com/events")

# %%
rb
# Out:
# <Response [200]>

# %%
rb.status_code
# Out:
# 200

# %%
rb.encoding
# Out:
# 'utf-8'

# %%
rb.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
rb.request
# Out:
# <PreparedRequest [GET]>

# %%
rb.request
# Out:
# <PreparedRequest [GET]>

# %%
rb.content
# Out:
# b'[{"id":"14828003466","type":"PushEvent","actor":{"id":8130860,"login":"HwangWoonChun","display_login":"HwangWoonChun","gravatar_id":"","url":"https://api.github.com/users/HwangWoonChun","avatar_url":"https://avatars.githubusercontent.com/u/8130860?"},"repo":{"id":266699717,"name":"HwangWoonChun/SwiftUIRecture","url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture"},"payload":{"push_id":6354719574,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"95931a2f16686d1c663fad3351e514f51602d7f5","before":"44e514762f4a923dc8acd8eb2773f0cb89796984","commits":[{"sha":"95931a2f16686d1c663fad3351e514f51602d7f5","author":{"email":"mmxsound077@gmail.com","name":"Pissed IOS Developer"},"message":"Update SwiftUI_09.md","distinct":true,"url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture/commits/95931a2f16686d1c663fad3351e514f51602d7f5"}]},"public":true,"created_at":"2021-01-15T04:09:29Z"},{"id":"14828003467","type":"PushEvent","actor":{"id":18639002,"login":"markita
# ...

# %%
rb.raw

# %%
rb.content
# Out:
# b'[{"id":"14828003466","type":"PushEvent","actor":{"id":8130860,"login":"HwangWoonChun","display_login":"HwangWoonChun","gravatar_id":"","url":"https://api.github.com/users/HwangWoonChun","avatar_url":"https://avatars.githubusercontent.com/u/8130860?"},"repo":{"id":266699717,"name":"HwangWoonChun/SwiftUIRecture","url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture"},"payload":{"push_id":6354719574,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"95931a2f16686d1c663fad3351e514f51602d7f5","before":"44e514762f4a923dc8acd8eb2773f0cb89796984","commits":[{"sha":"95931a2f16686d1c663fad3351e514f51602d7f5","author":{"email":"mmxsound077@gmail.com","name":"Pissed IOS Developer"},"message":"Update SwiftUI_09.md","distinct":true,"url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture/commits/95931a2f16686d1c663fad3351e514f51602d7f5"}]},"public":true,"created_at":"2021-01-15T04:09:29Z"},{"id":"14828003467","type":"PushEvent","actor":{"id":18639002,"login":"markita
# ...

# %%
rb.text
# Out:
# '[{"id":"14828003466","type":"PushEvent","actor":{"id":8130860,"login":"HwangWoonChun","display_login":"HwangWoonChun","gravatar_id":"","url":"https://api.github.com/users/HwangWoonChun","avatar_url":"https://avatars.githubusercontent.com/u/8130860?"},"repo":{"id":266699717,"name":"HwangWoonChun/SwiftUIRecture","url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture"},"payload":{"push_id":6354719574,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"95931a2f16686d1c663fad3351e514f51602d7f5","before":"44e514762f4a923dc8acd8eb2773f0cb89796984","commits":[{"sha":"95931a2f16686d1c663fad3351e514f51602d7f5","author":{"email":"mmxsound077@gmail.com","name":"Pissed IOS Developer"},"message":"Update SwiftUI_09.md","distinct":true,"url":"https://api.github.com/repos/HwangWoonChun/SwiftUIRecture/commits/95931a2f16686d1c663fad3351e514f51602d7f5"}]},"public":true,"created_at":"2021-01-15T04:09:29Z"},{"id":"14828003467","type":"PushEvent","actor":{"id":18639002,"login":"markital
# ...

# %%
ra.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-law.gif" itemprop="image"><meta content="Celebrating Dr. James Naismith" property="twitter:title"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="twitter:description"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="og:image"><meta content="784" property="og:image:width"><meta content="400" property="og:image:height"
# ...

# %%
ra.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-law.gif" itemprop="image"><meta content="Celebrating Dr. James Naismith" property="twitter:title"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="twitter:description"><meta content="Celebrating Dr. James Naismith! #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2021/celebrating-dr-james-naismith-6753651837108603-2xa.gif" property="og:image"><meta content="784" property="og:image:width"><meta content="400" property="og:image:height">
# ...

# %%
ra.headers
# Out:
# {'date': 'Fri, 15 Jan 2021 03:54:27 GMT', 'expires': '-1', 'cache-control': 'private, max-age=0', 'content-type': 'text/html; charset=ISO-8859-1', 'p3p': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'content-encoding': 'gzip', 'server': 'gws', 'x-xss-protection': '0', 'x-frame-options': 'SAMEORIGIN', 'set-cookie': '1P_JAR=2021-01-15-03; expires=Sun, 14-Feb-2021 03:54:27 GMT; path=/; domain=.google.co.in; Secure, NID=207=oWjkv1BMODvOe6oDDRtW53U6yEpTvoo9Ww4tB0CE9rXQ4UTH6pJZ579ee6NehO-VwqMC8KVAVk35FVm6sH2iBlbP43zjGowLl1dGLqriJsZJAqUrlJyoGJHANol27ONAuLDsxoKsR-o2Bm2BPJ4KCkftCP7GTD31GJUEG-gyu-Y; expires=Sat, 17-Jul-2021 03:54:27 GMT; path=/; domain=.google.co.in; HttpOnly', 'alt-svc': 'h3-29=":443"; ma=2592000,h3-T051=":443"; ma=2592000,h3-Q050=":443"; ma=2592000,h3-Q046=":443"; ma=2592000,h3-Q043=":443"; ma=2592000,quic=":443"; ma=2592000; v="46,43"', 'transfer-encoding': 'chunked'}

# %%
rb.headers
# Out:
# {'date': 'Fri, 15 Jan 2021 04:14:29 GMT', 'content-type': 'application/json; charset=utf-8', 'server': 'GitHub.com', 'status': '200 OK', 'cache-control': 'public, max-age=60, s-maxage=60', 'vary': 'Accept, Accept-Encoding, Accept, X-Requested-With, Accept-Encoding', 'etag': 'W/"f1f4625a6417d82fce3466434b7a7fc43d3214bc54d4d3b231a6a65baa07d701"', 'last-modified': 'Fri, 15 Jan 2021 04:09:29 GMT', 'x-poll-interval': '60', 'x-github-media-type': 'github.v3; format=json', 'link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'access-control-allow-origin': '*', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-conten
# ...

# %%
rc = requests.get("https://google.co.in", timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     133             conn = connection.create_connection(
# --> 134                 (self.host, self.port), self.timeout, **extra_kw)
#     135
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      87     if err is not None:
# ---> 88         raise err
#      89     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      77                 sock.bind(source_address)
# ---> 78             sock.connect(sa)
#      79             return sock
#
# timeout: timed out
#
# ...

# %%
rc = requests.get("https://google.co.in", timeout=1.0)

# %%
rc.status_code
# Out:
# 200

# %%
rc = requests.get("https://google.co.in", timeout=0.01)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     133             conn = connection.create_connection(
# --> 134                 (self.host, self.port), self.timeout, **extra_kw)
#     135
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      87     if err is not None:
# ---> 88         raise err
#      89     else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      77                 sock.bind(source_address)
# ---> 78             sock.connect(sa)
#      79             return sock
#
# timeout: timed out
#
# ...

# %%
rc.status_code
# Out:
# 200

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
rd = requests.get("https://www.oreilly.com/free/")

# %%
rd.status_code
# Out:
# 200

# %%
rd.headers
# Out:
# {'server': 'Apache/2.4.7 (Ubuntu)', 'last-modified': 'Thu, 14 Jan 2021 09:31:50 GMT', 'accept-ranges': 'bytes', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'content-type': 'text/html', 'cache-control': 'max-age=13258', 'expires': 'Fri, 15 Jan 2021 08:10:00 GMT', 'date': 'Fri, 15 Jan 2021 04:29:02 GMT', 'content-length': '62329', 'connection': 'keep-alive', 'set-cookie': 'akaalb_OReillyALB=~op=www_oreilly_com_ALB_90_SEB:dc1_sebastopol|~rv=100~m=dc1_sebastopol:0|~os=ea59de9527866dfb0dcb25ebf250c4a3~id=fb8e13ee7166e30e42f04928c24ede11; path=/; Secure; SameSite=None'}

# %%
from bs4 import BeautifulSoup

# %%
rd_cont = rd.content

# %%
rd_soup = BeautifulSoup(rd_cont)

# %%
type(rd_soup)
# Out:
# bs4.BeautifulSoup

# %%
rd_soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <style type="text/css">
# li.GlobalNavInfo.right { width: 145px; }
# </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!--chartbeat-->
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <title>Free O'Reilly Books, Ebooks, Webcasts, Conference Sessions, Tutorials, Videos - O'Reilly Media</title>
# <meta content="free O'Reilly tech books,free online books,free ebooks,free webcasts,free online events,free conference session,free tech tutorials,open books,O'Reilly Media,O'Reilly Media" name="keywords"/>
# <meta content="A compilation of O'Reilly Media's free products - ebooks, online books, webcast, conference sessions, tutorials, and videos" name="description"/>
# <meta content="2021-01-14" name="date"/>
# <meta content="2015-11-17" name="search_date"/>
# ...

# %%
samples = rd_soup.find_all("a", "item-title")

# %%
samples[0]
# Out:
# <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781449374433_sampler.pdf">
# Android Cookbook
# </a>

# %%
len(samples)
# Out:
# 1134

# %%
books = {}

# %%
type(samples)
# Out:
# bs4.element.ResultSet

# %%
for x in samples:
    name = x.string.strip()
    print(name)
# Out:
# Android Cookbook
# Think Perl 6
# Spock: Up and Running
# iPhone: The Missing Manual
# R for Data Science
# Building Software Teams
# macOS Sierra: The Missing Manual
# Practical Machine Learning with H2O
# The Kerbal Player's Guide
# CSS Refactoring
# High Performance Images
# Funded
# OpenShift for Developers
# Juniper MX Series
# Type Inheritance and Relational Theory
# Mastering CloudForms Automation
# Learning Rails 5
# Microservice Architecture
# Data Analytics with Hadoop
# Swift Development for the Apple Watch
# Learning Node
# Moodle 3.x Teaching Techniques
# Unity 5.x Game Development Blueprints
# Flux Architecture
# Mastering Drupal 8 Views
# Python Geospatial Development
# Expert Python Programming
# Internet of Things with Python
# Practical Mobile Forensics
# Cardboard VR Projects for Android
# Streaming Architecture
# Puppet for Containerization
# Android Sensor Programming By Example
# Machine Learning in Java
# 3D Printing Designs: Design an SD Card Holder
# ...

# %%
for x in samples:
    name = x.string.strip()
    print(x.attrs['href'])
# Out:
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781449374433_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491923290_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491979242_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491910399_Sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491951774_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491977231_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491964606_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491913055_Sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491906422_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491925805_sampler.pdf
# http://cdn.oreillystatic.com/oreilly/booksamplers/9781491940266_sampler.pdf
# ...

# %%
for x in samples:
    name = x.string.strip()
    books[name] = x.attrs['href']

# %%
books
# Out:
# {'Android Cookbook': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781449374433_sampler.pdf',
#  'Think Perl 6': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf',
#  'Spock: Up and Running': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491923290_sampler.pdf',
#  'iPhone: The Missing Manual': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491979242_sampler.pdf',
#  'R for Data Science': 'http://cdn.oreillystatic.com/oreilly/booksamplers/packt/9781784390860_Sample.pdf',
#  'Building Software Teams': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491951774_sampler.pdf',
#  'macOS Sierra: The Missing Manual': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491977231_sampler.pdf',
#  'Practical Machine Learning with H2O': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491964606_sampler.pdf',
#  "The Kerbal Player's Guide": 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491913055_Sampler.pdf',
# ...

# %%
list(books.keys())
# Out:
# ['Android Cookbook',
#  'Think Perl 6',
#  'Spock: Up and Running',
#  'iPhone: The Missing Manual',
#  'R for Data Science',
#  'Building Software Teams',
#  'macOS Sierra: The Missing Manual',
#  'Practical Machine Learning with H2O',
#  "The Kerbal Player's Guide",
#  'CSS Refactoring',
#  'High Performance Images',
#  'Funded',
#  'OpenShift for Developers',
#  'Juniper MX Series',
#  'Type Inheritance and Relational Theory',
#  'Mastering CloudForms Automation',
#  'Learning Rails 5',
#  'Microservice Architecture',
#  'Data Analytics with Hadoop',
#  'Swift Development for the Apple Watch',
#  'Learning Node',
#  'Moodle 3.x Teaching Techniques',
#  'Unity 5.x Game Development Blueprints',
#  'Flux Architecture',
#  'Mastering Drupal 8 Views',
#  'Python Geospatial Development',
#  'Expert Python Programming',
#  'Internet of Things with Python',
#  'Practical Mobile Forensics',
#  'Cardboard VR Projects for Android',
#  'Streaming Architecture',
# ...

# %%
books['Practical Linux Security Cookbook']
# Out:
# 'http://cdn.oreillystatic.com/oreilly/booksamplers/packt/9781785286421_Sample.pdf'
