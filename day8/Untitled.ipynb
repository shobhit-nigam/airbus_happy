# %%
import app

# %%
import app

# %%
import os

# %%
os.chdir('/Users/shobhit/opt/anaconda3/lib/python3.7/site-packages')

# %%
os.listdir()
# Out:
# ['xlrd-1.2.0.dist-info',
#  'bson',
#  'olefile',
#  'boto',
#  'imageio-2.9.0.dist-info',
#  'mistune.py',
#  'gensim-3.8.0.dist-info',
#  'heapdict.py',
#  'pyasn1-0.4.8.dist-info',
#  'lief.cpython-37m-darwin.so',
#  'prompt_toolkit-3.0.7.dist-info',
#  'decorator-4.4.2.dist-info',
#  'astroid',
#  'flask',
#  'ipywidgets-7.5.1.dist-info',
#  'sortedcollections',
#  's3transfer-0.1.13-py3.7.egg-info',
#  'google_api_core-1.22.2-py3.7-nspkg.pth',
#  'terminado-0.8.3-py3.7.egg-info',
#  'conda_verify-3.4.2.dist-info',
#  'simplegeneric.py',
#  'async_timeout',
#  'rsa-4.6.dist-info',
#  'pandas-1.1.2.dist-info',
#  'appnope',
#  'packaging',
#  'seaborn-0.11.0.dist-info',
#  'blis-0.4.1.dist-info',
#  'snowballstemmer-2.0.0.dist-info',
#  'mkl_random-1.1.1.dist-info',
#  'ply',
#  'aiohttp',
#  'backports.tempfile-1.0.dist-info',
#  'pyasn1',
#  'urllib3-1.25.10.dist-info',
#  'lxml-4.5.2.dist-info',
#  'qdarkstyle',
#  'thinc',
#  'Flask_RESTful-0.3.8.dist-info',
# ...

# %%
'pack-2.1' in os.listdir()
# Out:
# False
