# %%
import os

os.getcwd()
# Out:
# '/Users/shobhit/Desktop/airbus_python/day6'

# %%
os.listdir()
# Out:
# ['complete-cohort-life-tables-1876-2018.csv',
#  'pandas_1.ipynb',
#  '.ipynb_checkpoints',
#  'rental-price-indexes-November-2020-csvs.csv',
#  'national-population-estimates-at-30-june-2018-components-of-population-change-csv.csv']

# %%
import pandas as pd

# %%
dfa = pd.read_csv("rental-price-indexes-November-2020-csvs.csv")

# %%
dfa.shape
# Out:
# (1182, 10)

# %%
dfa
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 0     CPIM.SE1041F   2006.11      1000  FINAL  Index     CPI
# 1     CPIM.SE1041F   2006.12       995  FINAL  Index     CPI
# 2     CPIM.SE1041F   2007.01      1007  FINAL  Index     CPI
# 3     CPIM.SE1041F   2007.02      1012  FINAL  Index     CPI
# 4     CPIM.SE1041F   2007.03      1020  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                                   Group Series_title_1  \
# 0     CPI Monthly Rents (Broad Regions)       Auckland
# 1     CPI Monthly Rents (Broad Regions)       Auckland
# 2     CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
dfa.head(11)
# Out:
#          SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 0   CPIM.SE1041F   2006.11      1000  FINAL  Index     CPI
# 1   CPIM.SE1041F   2006.12       995  FINAL  Index     CPI
# 2   CPIM.SE1041F   2007.01      1007  FINAL  Index     CPI
# 3   CPIM.SE1041F   2007.02      1012  FINAL  Index     CPI
# 4   CPIM.SE1041F   2007.03      1020  FINAL  Index     CPI
# 5   CPIM.SE1041F   2007.04      1023  FINAL  Index     CPI
# 6   CPIM.SE1041F   2007.05      1045  FINAL  Index     CPI
# 7   CPIM.SE1041F   2007.06      1033  FINAL  Index     CPI
# 8   CPIM.SE1041F   2007.07      1037  FINAL  Index     CPI
# 9   CPIM.SE1041F   2007.08      1058  FINAL  Index     CPI
# 10  CPIM.SE1041F   2007.09      1051  FINAL  Index     CPI
#
#                                 Group Series_title_1  \
# 0   CPI Monthly Rents (Broad Regions)       Auckland
# 1   CPI Monthly Rents (Broad Regions)       Auckland
# 2   CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
dfa.tail()
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                              Group Series_title_1              Series_title_2  \
# 1177  CPI Monthly Rents (National)       National  Actual rentals for housing
# 1178  CPI Monthly Rents (National)       National  Actual rentals for housing
# 1179  CPI Monthly Rents (National)       National  Actual rentals for housing
# 1180  CPI Monthly Rents (National)       National  Actual rentals for housing
# 1181  CPI Monthly Rents (National)       National  Actual rentals for housing
#
#      Series_title_3
# 1177          Stock
# 1178          Stock
# 1179          Stock
# 1180          Stock
# 1181          Stock

# %%
dfa[['SER_REF', 'TIME_REF', 'DATA_VAL']]
# Out:
#            SER_REF  TIME_REF  DATA_VAL
# 0     CPIM.SE1041F   2006.11      1000
# 1     CPIM.SE1041F   2006.12       995
# 2     CPIM.SE1041F   2007.01      1007
# 3     CPIM.SE1041F   2007.02      1012
# 4     CPIM.SE1041F   2007.03      1020
# ...            ...       ...       ...
# 1177  CPIM.SE9041S   2020.07      1517
# 1178  CPIM.SE9041S   2020.08      1520
# 1179  CPIM.SE9041S   2020.09      1523
# 1180  CPIM.SE9041S   2020.10      1526
# 1181  CPIM.SE9041S   2020.11      1529
#
# [1182 rows x 3 columns]

# %%
dfa.iloc[24]
# Out:
# SER_REF                                CPIM.SE1041F
# TIME_REF                                    2008.11
# DATA_VAL                                       1059
# STATUS                                        FINAL
# UNITS                                         Index
# Subject                                         CPI
# Group             CPI Monthly Rents (Broad Regions)
# Series_title_1                             Auckland
# Series_title_2           Actual rentals for housing
# Series_title_3                                 Flow
# Name: 24, dtype: object

# %%
dfa.columns
# Out:
# Index(['SER_REF', 'TIME_REF', 'DATA_VAL', 'STATUS', 'UNITS', 'Subject',
#        'Group', 'Series_title_1', 'Series_title_2', 'Series_title_3'],
#       dtype='object')

# %%
list(dfa.columns)
# Out:
# ['SER_REF',
#  'TIME_REF',
#  'DATA_VAL',
#  'STATUS',
#  'UNITS',
#  'Subject',
#  'Group',
#  'Series_title_1',
#  'Series_title_2',
#  'Series_title_3']

# %%
dfa_columns = list(dfa.columns)

# %%
dfa
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 0     CPIM.SE1041F   2006.11      1000  FINAL  Index     CPI
# 1     CPIM.SE1041F   2006.12       995  FINAL  Index     CPI
# 2     CPIM.SE1041F   2007.01      1007  FINAL  Index     CPI
# 3     CPIM.SE1041F   2007.02      1012  FINAL  Index     CPI
# 4     CPIM.SE1041F   2007.03      1020  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                                   Group Series_title_1  \
# 0     CPI Monthly Rents (Broad Regions)       Auckland
# 1     CPI Monthly Rents (Broad Regions)       Auckland
# 2     CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
dfa.dtypes
# Out:
# SER_REF            object
# TIME_REF          float64
# DATA_VAL            int64
# STATUS             object
# UNITS              object
# Subject            object
# Group              object
# Series_title_1     object
# Series_title_2     object
# Series_title_3     object
# dtype: object

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SER_REF         1182 non-null   object
#  1   TIME_REF        1182 non-null   float64
#  2   DATA_VAL        1182 non-null   int64
#  3   STATUS          1182 non-null   object
#  4   UNITS           1182 non-null   object
#  5   Subject         1182 non-null   object
#  6   Group           1182 non-null   object
#  7   Series_title_1  1182 non-null   object
#  8   Series_title_2  1182 non-null   object
#  9   Series_title_3  1182 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 92.5+ KB

# %%
dfa['DATA_VAL']
# Out:
# 0       1000
# 1        995
# 2       1007
# 3       1012
# 4       1020
#         ...
# 1177    1517
# 1178    1520
# 1179    1523
# 1180    1526
# 1181    1529
# Name: DATA_VAL, Length: 1182, dtype: int64

# %%
dfa.DATA_VAL
# Out:
# 0       1000
# 1        995
# 2       1007
# 3       1012
# 4       1020
#         ...
# 1177    1517
# 1178    1520
# 1179    1523
# 1180    1526
# 1181    1529
# Name: DATA_VAL, Length: 1182, dtype: int64

# %%
dfa['DATA_VAL'].mean()
# Out:
# 1247.585448392555

# %%
dfa['DATA_VAL'].sum()
# Out:
# 1474646

# %%
dfa.describe()
# Out:
#           TIME_REF     DATA_VAL
# count  1182.000000  1182.000000
# mean   2013.444247  1247.585448
# std       4.064973   160.988587
# min    2006.110000   969.000000
# 25%    2010.050000  1106.000000
# 50%    2013.110000  1214.000000
# 75%    2017.050000  1385.000000
# max    2020.110000  1656.000000

# %%
dfa['STATUS'].nunique()
# Out:
# 1

# %%
dfa_columns
# Out:
# ['SER_REF',
#  'TIME_REF',
#  'DATA_VAL',
#  'STATUS',
#  'UNITS',
#  'Subject',
#  'Group',
#  'Series_title_1',
#  'Series_title_2',
#  'Series_title_3']

# %%
dfa['UNITS'].unique()
# Out:
# array(['Index'], dtype=object)

# %%
dfa['Subject'].value_counts()
# Out:
# CPI    1182
# Name: Subject, dtype: int64

# %%
dfa['Series_title_1'].value_counts()
# Out:
# National                337
# Rest of South Island    169
# Canterbury              169
# Rest of North Island    169
# Auckland                169
# Wellington              169
# Name: Series_title_1, dtype: int64

# %%
dfa['Series_title_3'].value_counts()
# Out:
# Flow     1014
# Stock     168
# Name: Series_title_3, dtype: int64

# %%
dfa['Group'].value_counts()
# Out:
# CPI Monthly Rents (Broad Regions)    845
# CPI Monthly Rents (National)         337
# Name: Group, dtype: int64

# %%
dfa
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 0     CPIM.SE1041F   2006.11      1000  FINAL  Index     CPI
# 1     CPIM.SE1041F   2006.12       995  FINAL  Index     CPI
# 2     CPIM.SE1041F   2007.01      1007  FINAL  Index     CPI
# 3     CPIM.SE1041F   2007.02      1012  FINAL  Index     CPI
# 4     CPIM.SE1041F   2007.03      1020  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                                   Group Series_title_1  \
# 0     CPI Monthly Rents (Broad Regions)       Auckland
# 1     CPI Monthly Rents (Broad Regions)       Auckland
# 2     CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
# condition dfa['DATA_VAL'] > 1500

# %%
dfa [dfa['DATA_VAL'] > 1500]
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 138   CPIM.SE1041F   2018.05      1503  FINAL  Index     CPI
# 143   CPIM.SE1041F   2018.10      1520  FINAL  Index     CPI
# 146   CPIM.SE1041F   2019.01      1513  FINAL  Index     CPI
# 147   CPIM.SE1041F   2019.02      1522  FINAL  Index     CPI
# 148   CPIM.SE1041F   2019.03      1533  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                                   Group Series_title_1  \
# 138   CPI Monthly Rents (Broad Regions)       Auckland
# 143   CPI Monthly Rents (Broad Regions)       Auckland
# 146   CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
dfa_1 = dfa [dfa['DATA_VAL'] > 1500]

# %%
dfa_1
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 138   CPIM.SE1041F   2018.05      1503  FINAL  Index     CPI
# 143   CPIM.SE1041F   2018.10      1520  FINAL  Index     CPI
# 146   CPIM.SE1041F   2019.01      1513  FINAL  Index     CPI
# 147   CPIM.SE1041F   2019.02      1522  FINAL  Index     CPI
# 148   CPIM.SE1041F   2019.03      1533  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 1177  CPIM.SE9041S   2020.07      1517  FINAL  Index     CPI
# 1178  CPIM.SE9041S   2020.08      1520  FINAL  Index     CPI
# 1179  CPIM.SE9041S   2020.09      1523  FINAL  Index     CPI
# 1180  CPIM.SE9041S   2020.10      1526  FINAL  Index     CPI
# 1181  CPIM.SE9041S   2020.11      1529  FINAL  Index     CPI
#
#                                   Group Series_title_1  \
# 138   CPI Monthly Rents (Broad Regions)       Auckland
# 143   CPI Monthly Rents (Broad Regions)       Auckland
# 146   CPI Monthly Rents (Broad Regions)       Auckland
# ...

# %%
dfa_1.sort_values(by='DATA_VAL')
# Out:
#            SER_REF  TIME_REF  DATA_VAL STATUS  UNITS Subject  \
# 1173  CPIM.SE9041S   2020.03      1501  FINAL  Index     CPI
# 166   CPIM.SE1041F   2020.09      1502  FINAL  Index     CPI
# 138   CPIM.SE1041F   2018.05      1503  FINAL  Index     CPI
# 487   CPIM.SE3041F   2019.04      1503  FINAL  Index     CPI
# 1007  CPIM.SE9041F   2020.05      1503  FINAL  Index     CPI
# ...            ...       ...       ...    ...    ...     ...
# 504   CPIM.SE3041F   2020.09      1635  FINAL  Index     CPI
# 506   CPIM.SE3041F   2020.11      1638  FINAL  Index     CPI
# 505   CPIM.SE3041F   2020.10      1639  FINAL  Index     CPI
# 337   CPIM.SE2041F   2020.11      1646  FINAL  Index     CPI
# 329   CPIM.SE2041F   2020.03      1656  FINAL  Index     CPI
#
#                                   Group        Series_title_1  \
# 1173       CPI Monthly Rents (National)              National
# 166   CPI Monthly Rents (Broad Regions)              Auckland
# ...

# %%
dfc = pd.read_csv('complete-cohort-life-tables-1876-2018.csv')

# %%
dfc
# Out:
#        yearofbirth     sex  age percentile     dx    ex    llx      lx  \
# 0             1876  female    0         05  12731  54.0  92431  100000
# 1             1876  female    0         95  12731  54.0  92431  100000
# 2             1876  female    0     median  12731  54.0  92431  100000
# 3             1876  female    1         05   2705  60.9  85916   87269
# 4             1876  female    1         95   2705  60.9  85916   87269
# ...            ...     ...  ...        ...    ...   ...    ...     ...
# 86653         2018    male   99         95   5833   3.2  20965   23799
# 86654         2018    male   99     median   3841   2.6  11476   13396
# 86655         2018    male  100         05   1342   2.0   3077    3762
# 86656         2018    male  100         95   4753   3.1  15859   18126
# 86657         2018    male  100     median   2938   2.5   8087    9555
#
#            mx      px      qx      sx
# 0      0.1377  0.8727  0.1273  0.9295
# ...

# %%
dfc.describe()
# Out:
#         yearofbirth           age            dx            ex           llx  \
# count  86658.000000  86658.000000  86658.000000  86658.000000  86658.000000
# mean    1947.000000     50.000000    961.383023     35.819092  74737.857867
# std       41.279773     29.154928   1436.276193     24.759425  28486.924691
# min     1876.000000      0.000000      0.000000      1.100000     30.000000
# 25%     1911.000000     25.000000    113.000000     12.700000  65098.000000
# 50%     1947.000000     50.000000    314.000000     33.600000  87068.000000
# 75%     1983.000000     75.000000   1266.000000     56.100000  95549.000000
# max     2018.000000    100.000000  14609.000000     95.400000  99658.000000
#
#                   lx            mx            px            qx            sx
# count   86658.000000  86658.000000  86658.000000  86658.000000  86658.000000
# mean    75226.402871      0.042902      0.961494      0.038506      0.960203
# ...

# %%
dfb = pd.read_csv("national-population-estimates-at-30-june-2018-components-of-population-change-csv.csv")

# %%
dfb
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   2008-06-30      F            8500.0        -3200.0             4200.0
# 1   2008-09-30      F            8100.0         2900.0             9800.0
# 2   2008-12-31      F            9200.0         2700.0            10700.0
# 3   2009-03-31      F            9300.0         5100.0            13200.0
# 4   2009-06-30      F            8400.0         1900.0             9100.0
# 5   2009-09-30      F            8500.0         7400.0            14700.0
# 6   2009-12-31      F            9100.0         6900.0            14800.0
# 7   2010-03-31      F            9900.0         4800.0            13500.0
# 8   2010-06-30      F            8700.0        -2600.0             5000.0
# 9   2010-09-30      F            8400.0         4800.0            12000.0
# 10  2010-12-31      F            8900.0         3400.0            11200.0
# 11  2011-03-31      F            8800.0          900.0             8600.0
# ...

# %%
dfb.dtypes
# Out:
# period                        object
# status                        object
# natural_increase             float64
# net_migration                float64
# population_change            float64
# percent_population_change    float64
# population                   float64
# dtype: object

# %%
type(dfb)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dfa['STATUS'])
# Out:
# pandas.core.series.Series

# %%
lista = [23, 56, 77, 10, 23]

sa = pd.Series(lista)

# %%
sa
# Out:
# 0    23
# 1    56
# 2    77
# 3    10
# 4    23
# dtype: int64

# %%
dicta = {'xx':22, 'yy':44, 'zz':100}

sb = pd.Series(dicta)

# %%
sb
# Out:
# xx     22
# yy     44
# zz    100
# dtype: int64

# %%
sb['xx']
# Out:
# 22

# %%
sb [sb > 40]
# Out:
# yy     44
# zz    100
# dtype: int64

# %%
dicta = {'dd':19, 'ee':10, 'zz':45}

sc = pd.Series({'dd':19, 'ee':10, 'zz':45})

# %%
sb
# Out:
# xx     22
# yy     44
# zz    100
# dtype: int64

# %%
sc
# Out:
# dd    19
# ee    10
# zz    45
# dtype: int64

# %%
sc*2
# Out:
# dd    38
# ee    20
# zz    90
# dtype: int64

# %%
sc
# Out:
# dd    19
# ee    10
# zz    45
# dtype: int64

# %%
sc.multiply(sb)
# Out:
# dd       NaN
# ee       NaN
# xx       NaN
# yy       NaN
# zz    4500.0
# dtype: float64

# %%
sc
# Out:
# dd    19
# ee    10
# zz    45
# dtype: int64

# %%
sb
# Out:
# xx     22
# yy     44
# zz    100
# dtype: int64

# %%
listd = [['pujara', 451], ['hanuma', 230], ['ashwin', 120], ['pant', 340]]

dfd = pd.DataFrame(listd)

# %%
dfd
# Out:
#         0    1
# 0  pujara  451
# 1  hanuma  230
# 2  ashwin  120
# 3    pant  340

# %%
listd = [['pujara', 451], ['hanuma', 230], ['ashwin', 120], ['pant', 340]]

dfd = pd.DataFrame(listd, columns=['player', 'val_index'])

# %%
dfd
# Out:
#    player  val_index
# 0  pujara        451
# 1  hanuma        230
# 2  ashwin        120
# 3    pant        340

# %%
breakfast = {'item':['poha', 'daliya', 'dosa', 'idli wada'], 'price':[45, 0, 55, 50]}

dfe = pd.DataFrame(breakfast, index=['indori', 'bihari', 'blr', 'madurai']) 

dfe
# Out:
#               item  price
# indori        poha     45
# bihari      daliya      0
# blr           dosa     55
# madurai  idli wada     50

# %%
dfe['nums'] = [2, 1, 1, 2]

# %%
dfe
# Out:
#               item  price  nums
# indori        poha     45     2
# bihari      daliya      0     1
# blr           dosa     55     1
# madurai  idli wada     50     2

# %%
dfe.rename(columns={'price':'rate'})
# Out:
#               item  rate  nums
# indori        poha    45     2
# bihari      daliya     0     1
# blr           dosa    55     1
# madurai  idli wada    50     2

# %%
dfe
# Out:
#               item  price  nums
# indori        poha     45     2
# bihari      daliya      0     1
# blr           dosa     55     1
# madurai  idli wada     50     2

# %%
dfe.rename(columns={'price':'rate'}, inplace=True)

# %%
dfe
# Out:
#               item  rate  nums
# indori        poha    45     2
# bihari      daliya     0     1
# blr           dosa    55     1
# madurai  idli wada    50     2

# %%
dfe['price'] = dfe['rate']*dfe['nums']

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100

# %%
entry = ['bacon', 80, 1, 80]

# %%
dfe.loc['blr']
# Out:
# item     dosa
# rate       55
# nums        1
# price      55
# Name: blr, dtype: object

# %%
dfe['lein'] = entry

# %%
dfe
# Out:
#               item  rate  nums  price   lein
# indori        poha    45     2     90  bacon
# bihari      daliya     0     1      0     80
# blr           dosa    55     1     55      1
# madurai  idli wada    50     2    100     80

# %%
dfe.drop(columns=['lein'], inplace=True)

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100

# %%
dfe.loc['lein'] = entry

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100
# lein         bacon    80     1     80

# %%
dfe[ dfe['item'] == 'dosa'].index
# Out:
# Index(['blr'], dtype='object')

# %%
type(dfe[ dfe['item'] == 'dosa'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
type(dfe[ dfe['item'] == 'dosa'].index.values)
# Out:
# numpy.ndarray

# %%
dfe[ dfe['item'] == 'dosa'].index.values
# Out:
# array(['blr'], dtype=object)

# %%
dfe[ dfe['item'] == 'dosa'].index
# Out:
# Index(['blr'], dtype='object')

# %%
dfe[ dfe['item'] == 'dosa'].index.values
# Out:
# array(['blr'], dtype=object)

# %%
dfe[ dfe['item'] == 'dosa'].index[0]
# Out:
# 'blr'

# %%
dfe[ dfe['item'] == 'dosa'].index.item()
# Out:
# 'blr'

# %%
pass

# %%
dfe['item'].str.find('dosa')
# Out:
# indori    -1
# bihari    -1
# blr        0
# madurai   -1
# lein      -1
# Name: item, dtype: int64

# %%
dfe[dfe['item'].str.find('dosa')==0]
# Out:
#      item  rate  nums  price
# blr  dosa    55     1     55

# %%
dfe[dfe['item'].str.contains('d')]
# Out:
#               item  rate  nums  price
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100

# %%
dfe[dfe['item'].str.contains('da')]
# Out:
#               item  rate  nums  price
# bihari      daliya     0     1      0
# madurai  idli wada    50     2    100

# %%
dfe[dfe['item'].str.contains('da', regex=False)]
# Out:
#               item  rate  nums  price
# bihari      daliya     0     1      0
# madurai  idli wada    50     2    100

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100
# lein         bacon    80     1     80

# %%
dfe['price'].sum()
# Out:
# 325

# %%
dfe['rate'].mean()
# Out:
# 46.0

# %%
os.getcwd()
# Out:
# '/Users/shobhit/Desktop/airbus_python/day6'

# %%
path = os.getcwd()

# %%
path = path + "/datasets"

# %%
import zipfile

# %%
with zipfile.ZipFile(path+'/bigmarket.zip') as za:
    with za.open("bigmarket.csv") as fa:
        dff = pd.read_csv(fa)

# %%
dff
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %%
dff['Month']
# Out:
# 0       Jan
# 1       Jan
# 2       Jan
# 3       Jan
# 4       Jan
# 5       Feb
# 6       Feb
# 7       Feb
# 8       Feb
# 9       Feb
# 10    March
# 11    March
# 12    March
# 13    March
# 14    March
# 15      Apr
# 16      Apr
# 17      Apr
# 18      Apr
# 19      Apr
# 20      May
# 21      May
# 22      May
# 23      May
# 24      May
# Name: Month, dtype: object

# %%
dff.iloc[20]
# Out:
# Month      May
# Store        A
# Sales    29487
# Name: 20, dtype: object

# %%
dff.iloc[10:20]
# Out:
#     Month Store  Sales
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880

# %%
dff.loc[10:20, ['Month', 'Sales']]
# Out:
#     Month  Sales
# 10  March  32961
# 11  March  26451
# 12  March  47814
# 13  March  36069
# 14  March  31874
# 15    Apr  27253
# 16    Apr  40241
# 17    Apr  47488
# 18    Apr  25432
# 19    Apr  33880
# 20    May  29487

# %%
dff.iloc[10:20, 0:2]
# Out:
#     Month Store
# 10  March     A
# 11  March     B
# 12  March     C
# 13  March     D
# 14  March     E
# 15    Apr     A
# 16    Apr     B
# 17    Apr     C
# 18    Apr     D
# 19    Apr     E

# %%
dff.iloc[0]['Month']
# Out:
# 'Jan'

# %%
dff
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %%
dff[dff['Month'] == 'Jan']
# Out:
#   Month Store  Sales
# 0   Jan     A  31037
# 1   Jan     B  20722
# 2   Jan     C  24557
# 3   Jan     D  34649
# 4   Jan     E  29795

# %%
dff[(dff['Month'] == 'Jan') & (dff['Sales']>30000)]
# Out:
#   Month Store  Sales
# 0   Jan     A  31037
# 3   Jan     D  34649

# %%
dff.sort_values(by='Sales', ascending=False)
# Out:
#     Month Store  Sales
# 12  March     C  47814
# 24    May     E  47594
# 17    Apr     C  47488
# 22    May     C  46482
# 23    May     D  46313
# 9     Feb     E  46267
# 16    Apr     B  40241
# 21    May     B  40001
# 13  March     D  36069
# 3     Jan     D  34649
# 19    Apr     E  33880
# 10  March     A  32961
# 14  March     E  31874
# 8     Feb     D  31454
# 0     Jan     A  31037
# 4     Jan     E  29795
# 20    May     A  29487
# 5     Feb     A  29133
# 7     Feb     C  28312
# 15    Apr     A  27253
# 11  March     B  26451
# 18    Apr     D  25432
# 2     Jan     C  24557
# 6     Feb     B  22695
# 1     Jan     B  20722

# %%
dff.sort_values(by='Sales', ascending=False)
# Out:
#     Month Store  Sales
# 12  March     C  47814
# 24    May     E  47594
# 17    Apr     C  47488
# 22    May     C  46482
# 23    May     D  46313
# 9     Feb     E  46267
# 16    Apr     B  40241
# 21    May     B  40001
# 13  March     D  36069
# 3     Jan     D  34649
# 19    Apr     E  33880
# 10  March     A  32961
# 14  March     E  31874
# 8     Feb     D  31454
# 0     Jan     A  31037
# 4     Jan     E  29795
# 20    May     A  29487
# 5     Feb     A  29133
# 7     Feb     C  28312
# 15    Apr     A  27253
# 11  March     B  26451
# 18    Apr     D  25432
# 2     Jan     C  24557
# 6     Feb     B  22695
# 1     Jan     B  20722

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100
# lein         bacon    80     1     80

# %%
dfe.sort_index()
# Out:
#               item  rate  nums  price
# bihari      daliya     0     1      0
# blr           dosa    55     1     55
# indori        poha    45     2     90
# lein         bacon    80     1     80
# madurai  idli wada    50     2    100

# %%
dfe['rate'].rank(method='min')
# Out:
# indori     2.0
# bihari     1.0
# blr        4.0
# madurai    3.0
# lein       5.0
# Name: rate, dtype: float64

# %%
dfe.at['bihari','rate']
# Out:
# 0

# %%
dfe.at['bihari','rate'] = 40

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya    40     1      0
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100
# lein         bacon    80     1     80

# %%
dfe.at['bihari','price'] = dfe.loc['bihari', 'rate'] * dfe.loc['bihari', 'nums']

# %%
dfe
# Out:
#               item  rate  nums  price
# indori        poha    45     2     90
# bihari      daliya    40     1     40
# blr           dosa    55     1     55
# madurai  idli wada    50     2    100
# lein         bacon    80     1     80

# %%
dff
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %%
pd.pivot_table(dff, index = ['Month'], values = ['Sales'], aggfunc='sum')
# Out:
#         Sales
# Month
# Apr    174294
# Feb    157861
# Jan    140760
# March  175169
# May    209877

# %%
data = {'phones':['samsung', 'iphone', 'vivo', 'lenovo', 'samsung', 'iphone', 'samsung'], 
       'sales':[5000, 4500, 5100, 6000, 4100, 2200, 3400], 
       'Colour':['Black', 'Blue', 'Blue', 'Black', 'Blue', 'Black', 'Blue']}

dfg = pd.DataFrame(data)

# %%
dfg
# Out:
#     phones  sales Colour
# 0  samsung   5000  Black
# 1   iphone   4500   Blue
# 2     vivo   5100   Blue
# 3   lenovo   6000  Black
# 4  samsung   4100   Blue
# 5   iphone   2200  Black
# 6  samsung   3400   Blue

# %%
pd.crosstab(dfg['phones'], dfg.Colour, rownames=['phones'], colnames=['Colour'])
# Out:
# Colour   Black  Blue
# phones
# iphone       1     1
# lenovo       1     0
# samsung      1     2
# vivo         0     1

# %%
pd.crosstab(dfg['phones'], dfg.Colour, rownames=['phones'], colnames=['Colour'], values=dfg['sales'], aggfunc='mean')
# Out:
# Colour    Black    Blue
# phones
# iphone   2200.0  4500.0
# lenovo   6000.0     NaN
# samsung  5000.0  3750.0
# vivo        NaN  5100.0

# %%
data = {'phones':['samsung', 'iphone', 'vivo', 'lenovo', 'samsung', 'iphone', 'samsung'], 
       'sales':[5000, 4500, 5100, 6000, 4100, 2200, 5000], 
       'Colour':['Black', 'Blue', 'Blue', 'Black', 'Blue', 'Black', 'Black']}

dfh = pd.DataFrame(data)

# %%
dfh
# Out:
#     phones  sales Colour
# 0  samsung   5000  Black
# 1   iphone   4500   Blue
# 2     vivo   5100   Blue
# 3   lenovo   6000  Black
# 4  samsung   4100   Blue
# 5   iphone   2200  Black
# 6  samsung   5000  Black

# %%
dfh.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
dfh.duplicated(keep=False)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
dfh.drop_duplicates()
# Out:
#     phones  sales Colour
# 0  samsung   5000  Black
# 1   iphone   4500   Blue
# 2     vivo   5100   Blue
# 3   lenovo   6000  Black
# 4  samsung   4100   Blue
# 5   iphone   2200  Black

# %%
dfh
# Out:
#     phones  sales Colour
# 0  samsung   5000  Black
# 1   iphone   4500   Blue
# 2     vivo   5100   Blue
# 3   lenovo   6000  Black
# 4  samsung   4100   Blue
# 5   iphone   2200  Black
# 6  samsung   5000  Black

# %%
dfb
# Out:
#         period status  natural_increase  net_migration  population_change  \
# 0   2008-06-30      F            8500.0        -3200.0             4200.0
# 1   2008-09-30      F            8100.0         2900.0             9800.0
# 2   2008-12-31      F            9200.0         2700.0            10700.0
# 3   2009-03-31      F            9300.0         5100.0            13200.0
# 4   2009-06-30      F            8400.0         1900.0             9100.0
# 5   2009-09-30      F            8500.0         7400.0            14700.0
# 6   2009-12-31      F            9100.0         6900.0            14800.0
# 7   2010-03-31      F            9900.0         4800.0            13500.0
# 8   2010-06-30      F            8700.0        -2600.0             5000.0
# 9   2010-09-30      F            8400.0         4800.0            12000.0
# 10  2010-12-31      F            8900.0         3400.0            11200.0
# 11  2011-03-31      F            8800.0          900.0             8600.0
# ...

# %%
dfb.drop(columns=['percent_population_change', 'population'])
# Out:
#         period status  natural_increase  net_migration  population_change
# 0   2008-06-30      F            8500.0        -3200.0             4200.0
# 1   2008-09-30      F            8100.0         2900.0             9800.0
# 2   2008-12-31      F            9200.0         2700.0            10700.0
# 3   2009-03-31      F            9300.0         5100.0            13200.0
# 4   2009-06-30      F            8400.0         1900.0             9100.0
# 5   2009-09-30      F            8500.0         7400.0            14700.0
# 6   2009-12-31      F            9100.0         6900.0            14800.0
# 7   2010-03-31      F            9900.0         4800.0            13500.0
# 8   2010-06-30      F            8700.0        -2600.0             5000.0
# 9   2010-09-30      F            8400.0         4800.0            12000.0
# 10  2010-12-31      F            8900.0         3400.0            11200.0
# 11  2011-03-31      F            8800.0          900.0             8600.0
# ...

# %%
dfb.drop(['percent_population_change', 'population'], axis = 1)
# Out:
#         period status  natural_increase  net_migration  population_change
# 0   2008-06-30      F            8500.0        -3200.0             4200.0
# 1   2008-09-30      F            8100.0         2900.0             9800.0
# 2   2008-12-31      F            9200.0         2700.0            10700.0
# 3   2009-03-31      F            9300.0         5100.0            13200.0
# 4   2009-06-30      F            8400.0         1900.0             9100.0
# 5   2009-09-30      F            8500.0         7400.0            14700.0
# 6   2009-12-31      F            9100.0         6900.0            14800.0
# 7   2010-03-31      F            9900.0         4800.0            13500.0
# 8   2010-06-30      F            8700.0        -2600.0             5000.0
# 9   2010-09-30      F            8400.0         4800.0            12000.0
# 10  2010-12-31      F            8900.0         3400.0            11200.0
# 11  2011-03-31      F            8800.0          900.0             8600.0
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dfe['rate'].plot()

plt.show()

# %%
plt.plot(dfe.index, dfe['rate'])
